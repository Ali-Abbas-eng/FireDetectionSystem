# %%
from data_prep import DistanceData, FireData
import numpy as np
from tqdm.auto import tqdm
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from data_prep import DistanceData, FireData
#       2 import numpy as np
#       3 from tqdm.auto import tqdm
#
# File D:\PycharmProjects\FireDetection\data_prep.py:16
#      12 # from detectron2.structures import BoxMode
#      13 os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
# ---> 16 class DistanceData(tf.keras.utils.Sequence, ABC):
#      17     """
#      18     DistanceData is a class that inherits from the Sequence class of Tensorflow and the ABC (Abstract Base Class).
#      19     This class is used to extract and store data for distance estimation.
#    (...)
#      42         ability to create CSV files for the data.
#      43     """
#      45     def __init__(self,
#      46                  batch_size: int = 64,
#      47                  min_depth: float = .6,
#    (...)
#      60                  unpack: bool = False,
#      61                  create_csv: bool = False):
#
# NameError: name 'tf' is not defined

# %%
def generate_data(data_generator):
    with tqdm(total=len(data_generator), desc='Iterating through Data') as progress_bar_:
        mean = .0
        std = .0
        maximum = -np.inf
        minimum = np.inf
        for index_ in range(len(data_generator)):
            x_, y_ = data_generator[index_]
            mean += np.mean(y_)
            std += np.std(y_) / (index_ + 1)
            maximum = max(maximum, np.max(y_))
            minimum = min(minimum, np.min(y_))
            progress_bar_.set_postfix_str(s=f'Mean: {mean / ((index_ + 1) * 4 * y_.size)} | '
                                            f'St dev.: {std} | Max: {maximum} | Min: {minimum}')
            progress_bar_.update()
    data_generator.plot()

# %%
train_data_generator_distance = DistanceData(batch_size=2, split='train', create_csv=True, unpack=True)
val_data_generator_distance = DistanceData(batch_size=2, split='val', create_csv=True, unpack=True)
generate_data(train_data_generator_distance)
generate_data(val_data_generator_distance)

# %%
data_generator_fire = FireData(batch_size=2, split='train', create_csv=True, unpack=False)
generate_data(data_generator_fire)
# Out:
# Creating Archive:   0%|          | 0/54922 [00:00<?, ?it/s]
# Creating Archive:   0%|          | 0/54922 [00:00<?, ?it/s]
# Iterating through Data:   0%|          | 0/109 [00:00<?, ?it/s]
